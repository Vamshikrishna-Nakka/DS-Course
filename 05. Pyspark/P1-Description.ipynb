# %%
BIG DATA:
    
Data is growing faster than processing speeds.Datasets are becoming huge.The companies like fb,google,linkedin,insta, etc.,
there data keep on increases that is the biggest problem for maintaining, Analysing or computing.

Mysql server, postsql server all these are standalone single servers. This single server takes data and push to database and
that database is held in some part of harddisk. The database or table kept growing it is difficult to process like simple
select command takes lot of time to get the result. and also at the same time memory wont be enough while processing. When 
we fetch data from harddisk it will put it on RAM then we can see on console. while data is tranfering from hardisk to ram 
then load will be on ram. and tranfer itself will take time

this is are the problems facing in datawarehousing solutions using single system.


but all these are in single machine and data keep on growing so not enough storage or ram for processing. so for handling
this problem Google invented a new methodology of processing data popularly known as MapReduce. Later, Doug Cutting and Mike
Cafarella, inspired by the white paper of the MapReduce framework, developed Hadoop to apply MapReduce concepts to an 
open-source software framework that supported the Nutch search engine project.a Hadoop for parallel processing or distributed
in multiple systems. Later on this became apache top project.


datawarehousing : this is basically for analytics they want hostorical and current data based on that they want to build a 
pattern, they want to some analysis like stock price predictions.

Big Data Analytics: The process of examining the large datasets to uncover information.(same as a data analysis but with 
parallel environment) this will help organisations to make informed business decisions.
    
huge market is now is cloud bigdata analytics.

# %%
Data can be categorized as Big Data based on various factors. The main concept common in all these factors is the amount of
data. Let us understand the characteristics of Big Data which we have broken down into 5 Vs:

Velocity: speed at which data arrives.
Volume : huge amount of data generated from credit cards, social media, IoT devices, smart home gadgets, videos, etc.
Variety : different types of data like structured(tables), unstructed (logs),semi-structed(nosql).
veracity: quality of the data. It depends on the reliability and accuracy of the content.
Value: most important part of Big Data.Having a vast amount of data is useless until we extract something meaningful from it.
    
    
we can solve all these 5 v using parallel enviroment.

# %%
Hadoop: It is a framework which is used to store bigdata across a spectrum of devices.this is done to help you to process 
       bigdata in parallel.
    
Important componets of hadoop ecosystem:
    
1) HDFS(Hadoop Distributed File System)  # storage layer
2) MapReduce   # processing layer 
3) YARN(Yet Another Resource Negotiator)       # resource negotiaer or manager

1) HDFS:- Hadoop HDFS Architecture follows a Master/Slave Architecture, where a cluster comprises of a single NameNode 
      (Master node) and all the other nodes are DataNodes (Slave nodes). 
    -  HDFS Splits files into blocks(partitions) and stores each block on a DataNode. Multiple DataNodes are linked to the
    master node in the cluster, the NameNode. The master node distributes replicas of these data blocks across the cluster.
    Master node will maintain all the data.
    
    
2) MapReduce: - It is a distributed computing system involves nodes (networked computers) that run processes in parallel and 
            communicate. It retrives the data from master table and processes according to mapreduce program.
           - The process of making a list of objects and running an operation over each object in the list (i.e., map) to 
             either produce a new list or calculate a single value (i.e., reduce). 
    
    MapReduce model involves two stages, Map and Reduce.
    
stage1: Map – a file in a Hadoop cluster is broken down into blocks, each with a default size of 128 MB. Depending upon the size,
        the input file is split into multiple chunks. A map task then runs for each chunk. The mapper class has mapper 
        functions that decide what operation is to be performed on each chunk. after mapper processes each line of the 
        input data (it is in the form of a file), and produces key – value pairs.
        
                    Input data → Mapper → list([key, value])
        
stage2 :Reduce – In the reducing phase, a reducer class performs operations on the data generated from the map tasks(i.e,, the 
            list of key – value pairs from Mapper function). It shuffles, sorts, and aggregates the intermediate key-value 
            pairs (tuples) into a set of smaller tuples(new set of key – value pairs). 
        
                   list([key, value]) → Reducer → list([key, list(values)])
            
            The smaller set of tuples is the final output and gets stored in HDFS.
        
3) YARN:-It allows the data stored in HDFS to be processed and run by various data processing engines such as batch 
    processing, stream processing, interactive processing, graph processing and many more. Thus the efficiency of the 
    system is increased with the use of YARN.
    - In Hadoop version 1.0 which is also referred to as MRV1(MapReduce Version 1), MapReduce performed both processing and
      resource management functions. It consisted of a Job Tracker which was the single master. The Job Tracker allocated 
      the resources, performed scheduling and monitored the processing jobs. It assigned map and reduce tasks on a number 
      of subordinate processes called the Task Trackers. The Task Trackers periodically reported their progress to the Job 
      Tracker.
    -Hadoop v2.0, YARN. YARN allows different data processing methods like graph processing, interactive processing, 
     stream processing as well as batch processing to run and process data stored in HDFS. Therefore YARN opens up Hadoop 
     to other types of distributed applications beyond MapReduce.
    -YARN also performs Job Scheduling. YARN performs all your processing activities by allocating resources and scheduling
     tasks.
    - YARN enabled the users to perform operations as per requirement by using a variety of tools like Spark for real-time 
      processing, Hive for SQL, HBase for NoSQL and others.

# %% [markdown]
# ![maptasks.jpg](attachment:maptasks.jpg)

# %%
In the era of Big Data, practitioners need more than ever fast and reliable tools to process streaming of data. 
Earlier tools like MapReduce were favorite but were slow. To overcome this issue, Spark offers a solution that is both 
fast and general-purpose. The main difference between Spark and MapReduce is that Spark runs computations in memory during 
the later on the hard disk. It allows high-speed access and data processing, reducing times from hours to minutes.

Mapreduce is not used because every problem in mapreduce has to be divided into key value pairs. In mapreduce it divides 
into mapper function and reducer function. so working on each will make slow. for smaller workloads, Spark’s data processing
speeds are up to 100x faster than MapReduce.

why all are using spark because 

1) All the tools in bubble every thing can be used in spark in single engine but have separate libraries to work as well but
   are outdated.
2) Speed
3) Ease of programming.

# %%
APACHE SPARK:
    
    Spark is a big data solution that has been proven to be easier and faster than Hadoop MapReduce.
    
    In 2009 in 'AMPlab' they have done a research project at UC Berkeley,The major intention behind this project was to create 
a cluster management framework that supports various computing systems based on clusters. they called that project as MESOS
(similar to YARN).

To test that MESOS they created a programming framework called 'SPARK'. if we write a program in spark it uses ram for 
faster processing and then that test was of MESOS was successful. but after that they didnt use that. Since it was released
to the public in 2010 it became as OpenSourced.

But in 2012  they started using Spark then it became an 'APACHE' project. they got to know that if you write a spark project
it will run faster than Mapreduce program. Later on in 2015 it become popular.

The founders(coders) of spark they give Spark to Apache as opensource and then it becomes a apache spark with different free
versions. but same founders who created  the 'SPARk' they created a company called 'DATA BRICKS' to sell spark. On databricks
only we have spark no others tools in that.

Spark is an independent project. not on hadoop but we can see top of hadoop.
Spark has 'NO storage' because its an execution engine.
neo4j  is NO SQL database for graph processing

Apache Spark basically written in Scala and later on to support Python with Spark, Apache Spark community released a tool,
API PySpark using Py4J. Py4J is a Java library that is integrated within PySpark and allows python to dynamically interface 
with JVM objects, hence to run PySpark you also need Java to be installed along with Python, and Apache Spark.Using PySpark,
you can work with RDDs in Python


Main features
    In-memory computation(processing) :means it use ram( if we have 10 gb data and 10 gb ram it uses ram and stores output 
    in cassendra). if there is no ram then it uses hardisk.

    Distributed processing using parallelize.
    Can be used with many cluster managers (Spark, Yarn, Mesos e.t.c)
    Fault-tolerant
    Immutable
    Lazy evaluation
    Cache & persistence
    Inbuild-optimization when using DataFrames
    Supports ANSI SQL



Spark Components
    Spark core(RDD)
    Shark (SQL)
    Spark Streaming & Structured Streaming (Streaming)
    MLLib (Machine Learning)
    GraphX (Graph Computation)

# %%
Data bricks team contributed more than 75% of the code added to spark in the past year.

1) best book to learn--"Spark the definative guide" (the author of spark wrote the book)
2) Apache documentation

# %% [markdown]
# <div> <img src="Capture.JPG" alt="Drawing" style="width: 600px;"/></div>

# %%
Spark works in a master-slave architecture where Master is called "Driver" and slaves are called "Workers or Executors". 

When you run a Spark application, Spark Driver creates a context that is an entry point to your application, and all 
operations (transformations and actions) are executed on worker nodes, and the resources are managed by Cluster Manager.

Cluster Manager Types : Standalone, Apache Mesos, Hadoop YARN, Kubernetes.
    
    
if we want to run a program in "Local" mode  a jvm container will be created, inside that there will be driver and executor
run. but the problem with local mode is we get only one container(only good for testing purpose).

If it is for  a "cluster" then when we submit a program we need ask YARN to give certain number of executors.
Example: we ask 4 executors with 5gb ram and some processor core. all these 4 nodes are in cluster and when we submit 
         program one machine automatically start that is driver machine. then now driver will push the code to all 4 nodes 
         at the same time and all machines will process the code. and now the output will comes back to driver and then in 
         the driver we need to write a logic store the output in hadoop/cassandra or any etc.,

Thes DRIVER machine(node ) is a APP Master.

if Driver machine goes down, in YARN we can configure restart application timer then it restart another AM in another machine
as driver. This application master(driver) is constant touch with resource/cluster manager.


Driver Program in the Apache Spark architecture calls the main program of an application and creates SparkContext. 
A SparkContext consists of all the basic functionalities. Spark Driver contains various other components such as DAG 
Scheduler, Task Scheduler, Backend Scheduler, and Block Manager, which are responsible for translating the user-written 
code into jobs that are actually executed on the cluster.

Spark Driver and SparkContext collectively watch over the job execution within the cluster. Spark Driver works with the 
Cluster Manager to manage various other jobs. The cluster Manager does the resource allocating work. And then, the job is 
split into multiple smaller tasks which are further distributed to worker nodes.

Whenever an RDD is created in the SparkContext, it can be distributed across many worker nodes and can also be cached there.

Worker nodes execute the tasks assigned by the Cluster Manager and return it back to the Spark Context.

An executor is responsible for the execution of these tasks. The lifetime of executors is the same as that of the Spark 
Application. If we want to increase the performance of the system, we can increase the number of workers so that the jobs 
can be divided into more logical portions.


In YARN -- spark dynamic execution allocator we can enble/disable it. if enable lauch 8 executors kill 7 but disable keeps all 8
executors.

# %% [markdown]
# ![ha.JPG](attachment:ha.JPG)

# %% [markdown]
# ![1-3.JPG](attachment:1-3.JPG)

# %%
Zookeeper is used for coordinational mechanism means the data will be registered which machines are active instead of 
manually pinging who is active we can directly as zookeeper.(only remembers who is alive who is not it wont do resource 
management)

zookeeper manages all machines. and this will be worked in all

# %%
if we have a spark cluster then we are streaming twitter data we can directly come to cluster to one any receiver but if 
something that receiver fail then the receiver will switch to another but it takes sometime by the time data will loose.
to avoid that we take a point to point tranfers we use they are "FLUME" and "KASKA" this will store data from twitter then 
from here we can pull to spark cluster if receiver fails also data will be availble in those 2 containers.

# %% [markdown]
# ![2.JPG](attachment:2.JPG)

# %%
from above we can use either yarn or mesos. tachyon is a filestore in 2009 it is renamed to "alluxio" project.

# %%
In Spark any data is represented as RDD(resilient distributed dataset). rdd is like a pointer.

example: from local machine we have 1gb file while reading we mention to divide into 4 partitions so each partition will go
to one executor. executor will execute a partition not a entire file. if wont do partition it comes a single so it is 
difficult.

no.of partitions will increase parallizium and processing speed get

if executor size is 10gb and partition size is 1gb then it can manage 10 partition there is no 100% data locality.


An executor is a container i.e, a JVM atleast one processor core is required to manage a container

if we request a 10gb ram for a executor then how much ram will get is 54% or 56% will get. because from 10gb system calls 
will take 10% and remaining 9gb from this we get only 60% since it is a jvm there will be garbage collection, jvm management
etc, takes memory at end we get only 54% or 56%(5.8gb for RDD remaining all system take)

# %%
#--------------IN CLI to work:-----------
# pyspark3 --help 

# pyspark3 # it is local mode
# pyspark3 --master yarn # to talk to yarn

# pyspark3 --master yarn --num-executors 4 --executor-memory 1500m #telling to yarn need 4 execuotr with 1500 memory

# sc._conf.getAll()  #to see spark configs from cli , live we can see
